# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/SeanNaren/warp-ctc.git
# !cd warp-ctc; mkdir build; cd build; cmake ..;make
# !cd warp-ctc/pytorch_binding;python setup.py install

# %%
import warpctc_pytorch

# %%
len("1213 ----33-------------------E")
# Out:
# 31

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# original_label = ' !\"#$%&\\\'()+-./0123456789:;=?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[]abcdefghijklmnopqrstuvwxyz´Éé'

# %%
os.path.isfile('datasets/viet_text_img/expr_viet/netCRNN_viet.pth')
# Out:
# False

# %%
# !python crnn_pytorch/doc_train.py --adadelta --trainroot "datasets/viet_text_img/train"  \
--trainlabel "datasets/viet_text_img/train_dict.json" \
--valroot "datasets/viet_text_img/val" --vallabel "datasets/viet_text_img/test_dict.json"  --cuda \
--pretrained "datasets/viet_text_img/expr_viet/netCRNN_24.pth" \
--alphabet " ,.0123456789ABCDGHIKLMNOPQRSTUVXY\\abcdefghijklmnopqrstuvwxyÀÁÂÃÒÓÔÙÚÝàáâãèéêìíòóôõùúýăĐđĨĩŨũƠơƯưẠạẢảấẦầẩẫẬậắặẹẽẾếềỂểễỆệỉỊịọỏốồỔổỗỘộỚớỜờỞởỡợỤụỦủứừửữỰựỳỷỹ" \
--displayInterval 14 --valInterval 29 --saveInterval 500 --lr 0.01 --nepoch 25 \
--imgH 32 --imgW 100 --n_test_disp 10 --expr_dir "datasets/viet_text_img/expr_viet"
# Out:
# Namespace(adadelta=True, adam=False, alphabet=' ,.0123456789ABCDGHIKLMNOPQRSTUVXY\\abcdefghijklmnopqrstuvwxyÀÁÂÃÒÓÔÙÚÝàáâãèéêìíòóôõùúýăĐđĨĩŨũƠơƯưẠạẢảấẦầẩẫẬậắặẹẽẾếềỂểễỆệỉỊịọỏốồỔổỗỘộỚớỜờỞởỡợỤụỦủứừửữỰựỳỷỹ', batchSize=64, beta1=0.5, cuda=True, displayInterval=14, expr_dir='datasets/viet_text_img/expr_viet', imgH=32, imgW=100, keep_ratio=False, lr=0.01, manualSeed=1234, n_test_disp=10, nepoch=25, ngpu=1, nh=256, pretrained='datasets/viet_text_img/expr_viet/netCRNN_24.pth', random_sample=False, saveInterval=500, trainlabel='datasets/viet_text_img/train_dict.json', trainroot='datasets/viet_text_img/train', valInterval=29, vallabel='datasets/viet_text_img/test_dict.json', valroot='datasets/viet_text_img/val', workers=2)
# CRNN(
#   (cnn): Sequential(
#     (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU(inplace=True)
#     (pooling0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ...

# %%
# !python crnn_pytorch/doc_train.py --adadelta --trainroot "datasets/vn_handwriting_data/train"  \
--trainlabel "datasets/vn_handwriting_data/train_dict.json" \
--valroot "datasets/vn_handwriting_data/val" --vallabel "datasets/vn_handwriting_data/test_dict.json"  --cuda \
 \
--displayInterval 30 --valInterval 90 --saveInterval 500 --lr 0.02 --pretrained "datasets/vn_handwriting_data/model_weights/netCRNN_4.pth" --nepoch 25 \
--imgH 32 --imgW 1150 --n_test_disp 10 --expr_dir "datasets/vn_handwriting_data/model_weights"
